# %% [markdown]
# This notebook explores the predictions using the allocation resource metric.

# %%
import pickle
import numpy as np
import pysal as ps
from scipy import sparse

from datetime import date
from datetime import timedelta

import pandas as pd
from pandas import TimeGrouper

import matplotlib.pyplot as plt

# %% [markdown]
# ## Plotting results without clustering

# %%
def printGrids(periodsAhead):
    # %matplotlib inline
    plt.close('all')
    fig, ax = plt.subplots(1, 3, figsize=(18,5), sharey=True)

    for result in results_mm_grid:
        ax[0].set_ylabel('% crime avoided')
        ax[0].plot(result)
        ax[0].legend()
    for result in results_ar_grid:
        ax[1].set_xlabel('Available resources')
        ax[1].set_title('{} week(s) ahead grid results'.format(periodsAhead))
        ax[1].plot(result)
        ax[1].legend()
    for result in results_h_grid:
        ax[2].plot(result)
        ax[2].legend()
    for result in results_mm_grid_1:
        ax[0].set_ylabel('crime avoided')
        ax[0].plot(result)
        ax[0].legend()
    for result in results_ar_grid_1:
        ax[1].set_xlabel('Available resources')
        ax[1].set_title('{} week(s) ahead grid results'.format(periodsAhead))
        ax[1].plot(result)
        ax[1].legend()
    for result in results_h_grid_1:
        ax[2].plot(result)
        ax[2].legend()
    plt.savefig('results/grid/{}week_grids.svg'.format(periodsAhead))
    plt.savefig('results/grid/{}week_grids.png'.format(periodsAhead), dpi=300)

# %% [markdown]
# ### 1 week ahead

# %%
periodsAhead = 1

# %%
pkl_file = open('results/grid/grid_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)

pkl_file_1 = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid_1, results_ar_grid_1, results_h_grid_1 = pickle.load(pkl_file_1)
printGrids(periodsAhead)

# %%
periodsAhead = 2

# %%
pkl_file = open('results/grid/grid_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)

pkl_file_1 = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid_1, results_ar_grid_1, results_h_grid_1 = pickle.load(pkl_file_1)
printGrids(periodsAhead)

# %% [markdown]
# ### 4 weeks ahead

# %%
periodsAhead = 4

# %%
pkl_file = open('results/grid/grid_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)

pkl_file_1 = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid_1, results_ar_grid_1, results_h_grid_1 = pickle.load(pkl_file_1)
printGrids(periodsAhead)

# %% [markdown]
# ### 8 weeks ahead

# %%
periodsAhead = 8

# %%
pkl_file = open('results/grid/grid_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)

pkl_file_1 = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid_1, results_ar_grid_1, results_h_grid_1 = pickle.load(pkl_file_1)
printGrids(periodsAhead)

# %%
printGrids(periodsAhead)

# %% [markdown]
# ### 16 weeks ahead

# %%
periodsAhead = 16

# %%
pkl_file = open('results/grid/grid_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)

pkl_file_1 = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid_1, results_ar_grid_1, results_h_grid_1 = pickle.load(pkl_file_1)
printGrids(periodsAhead)

# %%
periodsAhead = 64

pkl_file = open('results/grid/grid_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)

pkl_file_1 = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid_1, results_ar_grid_1, results_h_grid_1 = pickle.load(pkl_file_1)
printGrids(periodsAhead)

# %% [markdown]
# ## Plotting results with clustering

# %%
def printClusterGrids(periodsAhead):
    # %matplotlib inline
    plt.close('all')
    fig, ax = plt.subplots(1, 3, figsize=(18,5), sharey=True)
    print(results_mm_grid)
    print(results_ar_grid)
    print(results_h_grid)
    for result in results_mm_grid :
        ax[0].set_ylabel('crime avoided')
        ax[0].plot(result)
        ax[0].legend()
    for result in results_ar_grid:
        ax[1].set_xlabel('Available resources')
        ax[1].set_title('{} week(s) ahead cluster results'.format(periodsAhead))
        ax[1].plot(result)
        ax[1].legend()
    for result in results_h_grid:
        ax[2].plot(result)
        ax[2].legend()

    plt.savefig('results/cluster/{}week_clusters.svg'.format(periodsAhead))
    plt.savefig('results/cluster/{}week_clusters.png'.format(periodsAhead), dpi=300)
    plt.show()

# %% [markdown]
# ### 1 week ahead

# %%
periodsAhead = 1

# %%
pkl_file = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)
pkl_file.close()

# %%
printClusterGrids(periodsAhead)
# Out:
# [0       0.000000
# 250     0.101414
# 500     0.201201
# 750     0.300305
# 1000    0.399017
# 1250    0.497589
# 1500    0.595667
# 1750    0.692117
# 2000    0.789155
# 2250    0.884726
# 2500    0.951942
# 2750    0.971991
# 3000    0.982024
# Name: mm (0), dtype: float64, 0       0.000000
# 250     0.101546
# 500     0.201648
# 750     0.300992
# 1000    0.399804
# 1250    0.498720
# 1500    0.596734
# 1750    0.693388
# 2000    0.790369
# 2250    0.885964
# 2500    0.951380
# 2750    0.975031
# 3000    0.985440
# Name: mm (500), dtype: float64, 0       0.000000
# 250     0.101501
# 500     0.201595
# 750     0.300958
# 1000    0.399799
# 1250    0.498751
# 1500    0.596829
# 1750    0.693522
# 2000    0.790540
# 2250    0.886186
# 2500    0.948854
# 2750    0.974038
# 3000    0.985453
# Name: mm (1000), dtype: float64, 0       0.000000
# 250     0.101460
# 500     0.201563
# 750     0.301009
# 1000    0.399953
# 1250    0.498942
# 1500    0.597048
# 1750    0.693823
# 2000    0.790920
# 2250    0.886383
# 2500    0.940401
# 2750    0.969121
# 3000    0.983484
# Name: mm (1500), dtype: float64]
# [0       0.000000
# 250     0.101289
# 500     0.200357
# 750     0.298945
# 1000    0.397124
# 1250    0.495226
# 1500    0.592805
# 1750    0.689016
# 2000    0.785633
# 2250    0.880612
# 2500    0.949107
# 2750    0.970190
# 3000    0.981013
# Name: ar (0), dtype: float64, 0       0.000000
# 250     0.101421
# 500     0.200804
# 750     0.299632
# 1000    0.397911
# 1250    0.496357
# 1500    0.593872
# 1750    0.690288
# 2000    0.786847
# 2250    0.881849
# 2500    0.948542
# 2750    0.972985
# 3000    0.984530
# Name: ar (500), dtype: float64, 0       0.000000
# 250     0.101375
# 500     0.200752
# 750     0.299598
# 1000    0.397905
# 1250    0.496387
# 1500    0.593967
# 1750    0.690421
# 2000    0.787018
# 2250    0.882071
# 2500    0.946097
# 2750    0.971945
# 3000    0.984437
# Name: ar (1000), dtype: float64, 0       0.000000
# 250     0.101335
# 500     0.200719
# 750     0.299649
# 1000    0.398059
# 1250    0.496579
# 1500    0.594186
# 1750    0.690723
# 2000    0.787398
# 2250    0.882055
# 2500    0.937687
# 2750    0.966604
# 3000    0.982301
# Name: ar (1500), dtype: float64]
# [0       0.000000
# 250     0.101450
# 500     0.201322
# 750     0.300491
# 1000    0.399365
# 1250    0.498116
# 1500    0.596140
# 1750    0.692672
# 2000    0.790006
# 2250    0.885821
# 2500    0.952773
# 2750    0.972511
# 3000    0.982317
# Name: h (0), dtype: float64, 0       0.000000
# 250     0.101582
# 500     0.201769
# 750     0.301178
# 1000    0.400152
# 1250    0.499247
# 1500    0.597207
# 1750    0.693944
# 2000    0.791219
# 2250    0.887058
# 2500    0.952218
# 2750    0.975464
# 3000    0.985653
# Name: h (500), dtype: float64, 0       0.000000
# 250     0.101536
# 500     0.201716
# 750     0.301144
# 1000    0.400147
# 1250    0.499277
# 1500    0.597301
# 1750    0.694077
# 2000    0.791390
# 2250    0.887280
# 2500    0.949516
# 2750    0.974588
# 3000    0.985710
# Name: h (1000), dtype: float64, 0       0.000000
# 250     0.101496
# 500     0.201684
# 750     0.301195
# 1000    0.400300
# 1250    0.499469
# 1500    0.597521
# 1750    0.694379
# 2000    0.791771
# 2250    0.887456
# 2500    0.941001
# 2750    0.969705
# 3000    0.983817
# Name: h (1500), dtype: float64]

# %% [markdown]
# ### 2 weeks ahead

# %%
periodsAhead = 2

# %%
pkl_file = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)
pkl_file.close()

# %%
printClusterGrids(periodsAhead)
# Out:
# [0       0.000000
# 250     0.101356
# 500     0.201307
# 750     0.300533
# 1000    0.399209
# 1250    0.497788
# 1500    0.595739
# 1750    0.692120
# 2000    0.789003
# 2250    0.884561
# 2500    0.951391
# 2750    0.971379
# 3000    0.981603
# Name: mm (0), dtype: float64, 0       0.000000
# 250     0.101403
# 500     0.201589
# 750     0.301118
# 1000    0.400168
# 1250    0.499265
# 1500    0.597460
# 1750    0.694089
# 2000    0.791188
# 2250    0.882609
# 2500    0.930070
# 2750    0.959499
# 3000    0.979273
# Name: mm (2500), dtype: float64, 0       0.000000
# 250     0.101198
# 500     0.201267
# 750     0.300653
# 1000    0.399493
# 1250    0.498521
# 1500    0.596577
# 1750    0.693382
# 2000    0.781769
# 2250    0.831853
# 2500    0.879751
# 2750    0.912533
# 3000    0.936430
# Name: mm (5000), dtype: float64, 0       0.000000
# 250     0.100942
# 500     0.200682
# 750     0.299656
# 1000    0.398172
# 1250    0.496842
# 1500    0.564858
# 1750    0.614453
# 2000    0.663939
# 2250    0.713243
# 2500    0.762335
# 2750    0.811327
# 3000    0.853489
# Name: mm (7500), dtype: float64]
# [0       0.000000
# 250     0.101134
# 500     0.200280
# 750     0.298809
# 1000    0.397062
# 1250    0.495035
# 1500    0.592319
# 1750    0.688455
# 2000    0.784517
# 2250    0.878814
# 2500    0.947263
# 2750    0.968424
# 3000    0.979641
# Name: ar (0), dtype: float64, 0       0.000000
# 250     0.101181
# 500     0.200562
# 750     0.299395
# 1000    0.398021
# 1250    0.496512
# 1500    0.594040
# 1750    0.690424
# 2000    0.786702
# 2250    0.877117
# 2500    0.925890
# 2750    0.955785
# 3000    0.976503
# Name: ar (2500), dtype: float64, 0       0.000000
# 250     0.100977
# 500     0.200240
# 750     0.298929
# 1000    0.397345
# 1250    0.495768
# 1500    0.593158
# 1750    0.689717
# 2000    0.777609
# 2250    0.828371
# 2500    0.875700
# 2750    0.909033
# 3000    0.933004
# Name: ar (5000), dtype: float64, 0       0.000000
# 250     0.100720
# 500     0.199655
# 750     0.297933
# 1000    0.396024
# 1250    0.494089
# 1500    0.563328
# 1750    0.612104
# 2000    0.661149
# 2250    0.710599
# 2500    0.759297
# 2750    0.808371
# 3000    0.850361
# Name: ar (7500), dtype: float64]
# [0       0.000000
# 250     0.101398
# 500     0.201380
# 750     0.300824
# 1000    0.399583
# 1250    0.498292
# 1500    0.596178
# 1750    0.692762
# 2000    0.789813
# 2250    0.885583
# 2500    0.952030
# 2750    0.971676
# 3000    0.981750
# Name: h (0), dtype: float64, 0       0.000000
# 250     0.101445
# 500     0.201662
# 750     0.301410
# 1000    0.400542
# 1250    0.499769
# 1500    0.597899
# 1750    0.694731
# 2000    0.791998
# 2250    0.883677
# 2500    0.930682
# 2750    0.959978
# 3000    0.979511
# Name: h (2500), dtype: float64, 0       0.000000
# 250     0.101241
# 500     0.201339
# 750     0.300944
# 1000    0.399867
# 1250    0.499025
# 1500    0.597016
# 1750    0.694025
# 2000    0.782518
# 2250    0.832440
# 2500    0.880291
# 2750    0.913053
# 3000    0.936829
# Name: h (5000), dtype: float64, 0       0.000000
# 250     0.100984
# 500     0.200754
# 750     0.299948
# 1000    0.398546
# 1250    0.497346
# 1500    0.565358
# 1750    0.614912
# 2000    0.664486
# 2250    0.713905
# 2500    0.763173
# 2750    0.812295
# 3000    0.854295
# Name: h (7500), dtype: float64]

# %% [markdown]
# ### 4 weeks ahead

# %%
periodsAhead = 4

# %%
pkl_file = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)
pkl_file.close()

# %%
printClusterGrids(periodsAhead)
# Out:
# [0       0.000000
# 250     0.101595
# 500     0.201734
# 750     0.301045
# 1000    0.399650
# 1250    0.498386
# 1500    0.596155
# 1750    0.692477
# 2000    0.789316
# 2250    0.884901
# 2500    0.951196
# 2750    0.971075
# 3000    0.981447
# Name: mm (0), dtype: float64, 0       0.000000
# 250     0.101642
# 500     0.202016
# 750     0.301631
# 1000    0.400608
# 1250    0.499863
# 1500    0.597876
# 1750    0.694446
# 2000    0.791501
# 2250    0.882462
# 2500    0.929497
# 2750    0.959269
# 3000    0.978946
# Name: mm (2500), dtype: float64, 0       0.000000
# 250     0.101437
# 500     0.201694
# 750     0.301165
# 1000    0.399933
# 1250    0.499119
# 1500    0.596993
# 1750    0.693739
# 2000    0.781659
# 2250    0.831756
# 2500    0.879459
# 2750    0.912037
# 3000    0.935870
# Name: mm (5000), dtype: float64, 0       0.000000
# 250     0.101181
# 500     0.201108
# 750     0.300169
# 1000    0.398612
# 1250    0.497441
# 1500    0.564785
# 1750    0.614499
# 2000    0.664055
# 2250    0.713169
# 2500    0.762149
# 2750    0.810918
# 3000    0.852948
# Name: mm (7500), dtype: float64]
# [0       0.000000
# 250     0.101270
# 500     0.200676
# 750     0.299041
# 1000    0.396898
# 1250    0.494669
# 1500    0.591576
# 1750    0.687230
# 2000    0.783016
# 2250    0.876837
# 2500    0.945153
# 2750    0.967439
# 3000    0.978516
# Name: ar (0), dtype: float64, 0       0.000000
# 250     0.101318
# 500     0.200957
# 750     0.299627
# 1000    0.397857
# 1250    0.496146
# 1500    0.593297
# 1750    0.689199
# 2000    0.785201
# 2250    0.874977
# 2500    0.923641
# 2750    0.954022
# 3000    0.975228
# Name: ar (2500), dtype: float64, 0       0.000000
# 250     0.101113
# 500     0.200635
# 750     0.299161
# 1000    0.397181
# 1250    0.495402
# 1500    0.592414
# 1750    0.688492
# 2000    0.775939
# 2250    0.826964
# 2500    0.873924
# 2750    0.907156
# 3000    0.930812
# Name: ar (5000), dtype: float64, 0       0.000000
# 250     0.100857
# 500     0.200050
# 750     0.298165
# 1000    0.395860
# 1250    0.493724
# 1500    0.562533
# 1750    0.611315
# 2000    0.660361
# 2250    0.709212
# 2500    0.757866
# 2750    0.806473
# 3000    0.848545
# Name: ar (7500), dtype: float64]
# [0       0.000000
# 250     0.101552
# 500     0.201652
# 750     0.301047
# 1000    0.399799
# 1250    0.498653
# 1500    0.596222
# 1750    0.692797
# 2000    0.789914
# 2250    0.885415
# 2500    0.951548
# 2750    0.971075
# 3000    0.981429
# Name: h (0), dtype: float64, 0       0.000000
# 250     0.101600
# 500     0.201934
# 750     0.301632
# 1000    0.400758
# 1250    0.500131
# 1500    0.597942
# 1750    0.694766
# 2000    0.792099
# 2250    0.883002
# 2500    0.929775
# 2750    0.959517
# 3000    0.979145
# Name: h (2500), dtype: float64, 0       0.000000
# 250     0.101395
# 500     0.201612
# 750     0.301167
# 1000    0.400083
# 1250    0.499387
# 1500    0.597060
# 1750    0.694060
# 2000    0.782199
# 2250    0.832011
# 2500    0.879641
# 2750    0.912142
# 3000    0.935907
# Name: h (5000), dtype: float64, 0       0.000000
# 250     0.101139
# 500     0.201026
# 750     0.300170
# 1000    0.398761
# 1250    0.497708
# 1500    0.564882
# 1750    0.614678
# 2000    0.664336
# 2250    0.713612
# 2500    0.762792
# 2750    0.811486
# 3000    0.853439
# Name: h (7500), dtype: float64]

# %% [markdown]
# ### 8 weeks ahead

# %%
periodsAhead = 8

# %%
pkl_file = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)
pkl_file.close()

# %%
printClusterGrids(periodsAhead)
# Out:
# [0       0.000000
# 250     0.101607
# 500     0.201866
# 750     0.301210
# 1000    0.399967
# 1250    0.498987
# 1500    0.596741
# 1750    0.693116
# 2000    0.789698
# 2250    0.885365
# 2500    0.949927
# 2750    0.969460
# 3000    0.980255
# Name: mm (0), dtype: float64, 0       0.000000
# 250     0.101655
# 500     0.202148
# 750     0.301795
# 1000    0.400926
# 1250    0.500465
# 1500    0.598462
# 1750    0.695085
# 2000    0.791883
# 2250    0.882267
# 2500    0.927995
# 2750    0.957764
# 3000    0.977914
# Name: mm (2500), dtype: float64, 0       0.000000
# 250     0.101450
# 500     0.201826
# 750     0.301330
# 1000    0.400251
# 1250    0.499721
# 1500    0.597579
# 1750    0.694378
# 2000    0.780960
# 2250    0.830922
# 2500    0.878521
# 2750    0.910421
# 3000    0.934141
# Name: mm (5000), dtype: float64, 0       0.000000
# 250     0.101194
# 500     0.201240
# 750     0.300333
# 1000    0.398930
# 1250    0.498042
# 1500    0.564094
# 1750    0.614171
# 2000    0.663789
# 2250    0.712947
# 2500    0.761625
# 2750    0.810436
# 3000    0.851855
# Name: mm (7500), dtype: float64]
# [0       0.000000
# 250     0.101570
# 500     0.201309
# 750     0.300057
# 1000    0.398443
# 1250    0.496638
# 1500    0.594006
# 1750    0.690117
# 2000    0.785612
# 2250    0.879355
# 2500    0.943769
# 2750    0.965470
# 3000    0.977575
# Name: ar (0), dtype: float64, 0       0.000000
# 250     0.101617
# 500     0.201591
# 750     0.300642
# 1000    0.399401
# 1250    0.498115
# 1500    0.595726
# 1750    0.692086
# 2000    0.787797
# 2250    0.876048
# 2500    0.922906
# 2750    0.952535
# 3000    0.974374
# Name: ar (2500), dtype: float64, 0       0.000000
# 250     0.101412
# 500     0.201269
# 750     0.300177
# 1000    0.398726
# 1250    0.497371
# 1500    0.594844
# 1750    0.691379
# 2000    0.776609
# 2250    0.826929
# 2500    0.873660
# 2750    0.905980
# 3000    0.929681
# Name: ar (5000), dtype: float64, 0       0.000000
# 250     0.101156
# 500     0.200683
# 750     0.299180
# 1000    0.397405
# 1250    0.495599
# 1500    0.562457
# 1750    0.611840
# 2000    0.661231
# 2250    0.710370
# 2500    0.759129
# 2750    0.807107
# 3000    0.848665
# Name: ar (7500), dtype: float64]
# [0       0.000000
# 250     0.101574
# 500     0.201821
# 750     0.301321
# 1000    0.400244
# 1250    0.499368
# 1500    0.596823
# 1750    0.693582
# 2000    0.790445
# 2250    0.885915
# 2500    0.950254
# 2750    0.969475
# 3000    0.980399
# Name: h (0), dtype: float64, 0       0.000000
# 250     0.101621
# 500     0.202103
# 750     0.301906
# 1000    0.401202
# 1250    0.500845
# 1500    0.598543
# 1750    0.695551
# 2000    0.792630
# 2250    0.882705
# 2500    0.928021
# 2750    0.957991
# 3000    0.977936
# Name: h (2500), dtype: float64, 0       0.000000
# 250     0.101416
# 500     0.201781
# 750     0.301441
# 1000    0.400527
# 1250    0.500101
# 1500    0.597661
# 1750    0.694844
# 2000    0.781473
# 2250    0.831091
# 2500    0.878521
# 2750    0.910327
# 3000    0.933971
# Name: h (5000), dtype: float64, 0       0.000000
# 250     0.101160
# 500     0.201195
# 750     0.300444
# 1000    0.399206
# 1250    0.498423
# 1500    0.564216
# 1750    0.614378
# 2000    0.664070
# 2250    0.713325
# 2500    0.762349
# 2750    0.811008
# 3000    0.852321
# Name: h (7500), dtype: float64]

# %% [markdown]
# ### 16 weeks ahead

# %%
periodsAhead = 32

# %%
pkl_file = open('results/cluster/cluster_{}ahead.pkl'.format(periodsAhead), 'rb')
results_mm_grid, results_ar_grid, results_h_grid = pickle.load(pkl_file)
pkl_file.close()

# %%
printClusterGrids(periodsAhead)
# Out:
# [0       0.000000
# 250     0.102300
# 500     0.203180
# 750     0.303058
# 1000    0.402735
# 1250    0.502775
# 1500    0.600138
# 1750    0.697346
# 2000    0.794965
# 2250    0.890343
# 2500    0.943569
# 2750    0.963215
# 3000    0.975198
# Name: mm (0), dtype: float64, 0       0.000000
# 250     0.102348
# 500     0.203461
# 750     0.303643
# 1000    0.403693
# 1250    0.504252
# 1500    0.601859
# 1750    0.699315
# 2000    0.797150
# 2250    0.881214
# 2500    0.919535
# 2750    0.952552
# 3000    0.973445
# Name: mm (2500), dtype: float64, 0       0.000000
# 250     0.102143
# 500     0.203139
# 750     0.303178
# 1000    0.403018
# 1250    0.503508
# 1500    0.600976
# 1750    0.698608
# 2000    0.777768
# 2250    0.827500
# 2500    0.873124
# 2750    0.901837
# 3000    0.924467
# Name: mm (5000), dtype: float64, 0       0.000000
# 250     0.101887
# 500     0.202554
# 750     0.302181
# 1000    0.401697
# 1250    0.501830
# 1500    0.561238
# 1750    0.612456
# 2000    0.662638
# 2250    0.711818
# 2500    0.760972
# 2750    0.809588
# 3000    0.847316
# Name: mm (7500), dtype: float64]
# [0       0.000000
# 250     0.101931
# 500     0.202068
# 750     0.301253
# 1000    0.399955
# 1250    0.499112
# 1500    0.595951
# 1750    0.692189
# 2000    0.788223
# 2250    0.881204
# 2500    0.937772
# 2750    0.959554
# 3000    0.971892
# Name: ar (0), dtype: float64, 0       0.000000
# 250     0.101978
# 500     0.202350
# 750     0.301839
# 1000    0.400913
# 1250    0.500589
# 1500    0.597672
# 1750    0.694158
# 2000    0.790408
# 2250    0.874580
# 2500    0.914362
# 2750    0.947034
# 3000    0.969634
# Name: ar (2500), dtype: float64, 0       0.000000
# 250     0.101774
# 500     0.202028
# 750     0.301373
# 1000    0.400238
# 1250    0.499845
# 1500    0.596789
# 1750    0.693451
# 2000    0.773649
# 2250    0.822854
# 2500    0.867801
# 2750    0.897453
# 3000    0.920138
# Name: ar (5000), dtype: float64, 0       0.000000
# 250     0.101517
# 500     0.201443
# 750     0.300377
# 1000    0.398917
# 1250    0.498078
# 1500    0.558861
# 1750    0.608983
# 2000    0.658857
# 2250    0.707485
# 2500    0.756194
# 2750    0.804268
# 3000    0.842745
# Name: ar (7500), dtype: float64]
# [0       0.000000
# 250     0.102292
# 500     0.203097
# 750     0.303436
# 1000    0.403544
# 1250    0.503778
# 1500    0.601138
# 1750    0.698200
# 2000    0.796015
# 2250    0.891297
# 2500    0.943691
# 2750    0.962993
# 3000    0.975383
# Name: h (0), dtype: float64, 0       0.000000
# 250     0.102339
# 500     0.203379
# 750     0.304022
# 1000    0.404503
# 1250    0.505255
# 1500    0.602858
# 1750    0.700169
# 2000    0.798200
# 2250    0.881384
# 2500    0.919590
# 2750    0.952710
# 3000    0.973625
# Name: h (2500), dtype: float64, 0       0.000000
# 250     0.102135
# 500     0.203057
# 750     0.303556
# 1000    0.403827
# 1250    0.504511
# 1500    0.601976
# 1750    0.699462
# 2000    0.777963
# 2250    0.827442
# 2500    0.872974
# 2750    0.901493
# 3000    0.924138
# Name: h (5000), dtype: float64, 0       0.000000
# 250     0.101879
# 500     0.202471
# 750     0.302560
# 1000    0.402506
# 1250    0.502833
# 1500    0.561666
# 1750    0.613005
# 2000    0.663456
# 2250    0.713009
# 2500    0.762230
# 2750    0.810412
# 3000    0.847778
# Name: h (7500), dtype: float64]
